# %%
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs
from matplotlib.pylab import plt
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns #for styling the plots


import geopandas as gpd
import sklearn
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.mixture import GaussianMixture
from scipy.spatial.distance import cdist, pdist
from sklearn.cluster import DBSCAN

# %% [markdown]
# ## Load data

# %%
# family = pd.read_csv('familyGeo.csv')
# hpd_compl = pd.read_csv('hpdcomplaints_byCD_2013to2017.csv')
# nypd_compl = pd.read_csv('nypdcomplaints_byCD_2013to2017.csv')
# race = pd.read_csv('race_geo_clean.csv')
# econ = pd.read_csv('yearly_econ_pct_cd.csv')
# evic = pd.read_csv('yearly_evic_per1000_cd.csv')
# burden = pd.read_csv('yearly_severeburden_pct_cd.csv')

# %%
# questions

# family: what are 'Total' and 'Percent'?
# 
# general: take totals or %

# %%
family = pd.read_csv('familyGeo.csv')
# check if we drop totals or %
family_drop = ['Unnamed: 0', 'OBJECTID', 'Shape__Area', 'Shape__Length', 'geometry', 'LocationId', 'Total']
family.drop(columns=family_drop, inplace=True)
family.rename(columns={'BoroCD':'Location', 'Percent':'Family%'}, inplace=True)

hpd_compl = pd.read_csv('hpdcomplaints_byCD_2013to2017.csv')
hpd_compl.rename(columns={'# HPD Complaints':'hpd_compl', 'boro_cd':'Location', 'year':'Year'}, inplace=True)

nypd_compl = pd.read_csv('nypdcomplaints_byCD_2013to2017.csv')
nypd_compl.rename(columns={'Total # NYPD Complaints':'nypd_compl', 'CD':'Location'}, inplace=True)

race = pd.read_csv('race_geo_clean.csv')
# check if we drop totals or %
race_drop = ['White', 'Latino', 'Black', 'Asian', 'Other']
race.drop(columns=race_drop, inplace=True)
race.rename(columns={'LocationId':'Location', 'Other':'Race_other', '%Other':'Race_%other'}, inplace=True)

econ = pd.read_csv('yearly_econ_pct_cd.csv')
econ.drop(columns=['Unnamed: 0', 'Location'], inplace=True)
econ.rename(columns={'Fips':'Location'}, inplace=True)

evic = pd.read_csv('yearly_evic_per1000_cd.csv')
evic.drop(columns=['Unnamed: 0', 'Community District'], inplace=True)
evic.rename(columns={'CD_ID':'Location'}, inplace=True)
evic = evic[['Location', 'Year', 'Evic_rt']]

burden = pd.read_csv('yearly_severeburden_pct_cd.csv')
burden.drop(columns=['Unnamed: 0', 'Location'], inplace=True)
burden.rename(columns={'Fips':'Location'}, inplace=True)

# %%
family.head()
# Out:
#    Location    Year  Family%
# 0       101  2015.0  0.14185
# 1       101  2016.0  0.18184
# 2       101  2013.0  0.16456
# 3       101  2017.0  0.16096
# 4       101  2014.0  0.13802

# %%
hpd_compl.head()
# Out:
#    Location  Year  hpd_compl
# 0       101  2013          5
# 1       101  2014        540
# 2       101  2015       1244
# 3       101  2016       1157
# 4       101  2017        897

# %%
nypd_compl.head()
# Out:
#    Location  Year  nypd_compl
# 0       101  2013        4728
# 1       101  2014        4567
# 2       101  2015        4867
# 3       101  2016        5492
# 4       101  2017        5358

# %%
race.head()
# Out:
#    Location  Year   %White  %Latino   %Black   %Asian  Race_%other max_race
# 0       101  2013  0.71920  0.06831  0.02233  0.15648      0.03368    White
# 1       101  2014  0.72273  0.06887  0.02319  0.15057      0.03464    White
# 2       101  2015  0.71679  0.06837  0.02263  0.15731      0.03490    White
# 3       101  2016  0.71615  0.06966  0.02227  0.15905      0.03288    White
# 4       101  2017  0.72039  0.06416  0.02304  0.15709      0.03532    White

# %%
econ.head()
# Out:
#    Year  Location  poverty_pct  unemployment_rt  median_income  \
# 0  2013       401      0.19033          0.09626    56018.80292
# 1  2014       401      0.17129          0.09000    60824.80189
# 2  2015       401      0.16715          0.06100    62240.66208
# 3  2016       401      0.13800          0.05600    64354.43973
# 4  2018       401      0.13941          0.04400    68665.94375
#
#    limited_english_pct
# 0                0.157
# 1                0.149
# 2                0.154
# 3                0.173
# 4                0.131

# %%
evic.head()
# Out:
#    Location  Year    Evic_rt
# 0       101  2013  43.711095
# 1       101  2014  35.407584
# 2       101  2015  28.157475
# 3       101  2016  26.383320
# 4       101  2017  22.314438

# %%
burden.head()
# Out:
#    Year  severe_burden_pct  Location
# 0  2013            0.19520       101
# 1  2015            0.18744       101
# 2  2014            0.18224       101
# 3  2017            0.16966       101
# 4  2016            0.17581       101

# %%
df = evic.merge(family, left_on=['Location', 'Year'], right_on=['Location', 'Year'])
df = df.merge(hpd_compl, left_on=['Location', 'Year'], right_on=['Location', 'Year'])
df = df.merge(nypd_compl, left_on=['Location', 'Year'], right_on=['Location', 'Year'])
df = df.merge(race, left_on=['Location', 'Year'], right_on=['Location', 'Year'])
df = df.merge(econ, left_on=['Location', 'Year'], right_on=['Location', 'Year'])
df = df.merge(burden, left_on=['Location', 'Year'], right_on=['Location', 'Year'])
df
# Out:
#      Location  Year    Evic_rt  Family%  hpd_compl  nypd_compl   %White  \
# 0         101  2013  43.711095  0.16456          5        4728  0.71920
# 1         101  2014  35.407584  0.13802        540        4567  0.72273
# 2         101  2015  28.157475  0.14185       1244        4867  0.71679
# 3         101  2016  26.383320  0.18184       1157        5492  0.71615
# 4         101  2017  22.314438  0.16096        897        5358  0.72039
# ..        ...   ...        ...      ...        ...         ...      ...
# 275       407  2013  63.054351  0.29155         15        7941  0.28818
# 276       407  2014  57.068165  0.29129       1596        7992  0.28154
# 277       407  2015  54.261820  0.26298       3604        7757  0.27036
# 278       407  2016  48.648503  0.27922       3357        8185  0.25559
# 279       407  2017  46.482818  0.26578       3655        8378  0.25665
#
#      %Latino   %Black   %Asian  Race_%other max_race  poverty_pct  \
# 0    0.06831  0.02233  0.15648      0.03368    White      0.07797
# 1    0.06887  0.02319  0.15057      0.03464    White      0.07962
# 2    0.06837  0.02263  0.15731      0.03490    White      0.07366
# 3    0.06966  0.02227  0.15905      0.03288    White      0.08000
# 4    0.06416  0.02304  0.15709      0.03532    White      0.08800
# ..       ...      ...      ...          ...      ...          ...
# 275  0.17420  0.01910  0.49045      0.02806    Asian      0.16936
# 276  0.16930  0.01955  0.50286      0.02675    Asian      0.18822
# 277  0.17063  0.02009  0.51300      0.02591    Asian      0.15407
# 278  0.17569  0.02142  0.52176      0.02554    Asian      0.15900
# 279  0.17396  0.02098  0.52635      0.02206    Asian      0.16200
#
#      unemployment_rt  median_income  limited_english_pct  severe_burden_pct
# 0            0.04200   137750.63212              0.04100            0.19520
# 1            0.04400   129921.14556              0.03700            0.18224
# 2            0.04200   131814.92691              0.03300            0.18744
# 3            0.03900   146178.73514              0.02700            0.17581
# 4            0.02600   151098.52355              0.03162            0.16966
# ..               ...            ...                  ...                ...
# 275          0.06918    55502.14599              0.40600            0.34609
# 276          0.05700    56323.66494              0.41500            0.36510
# 277          0.04700    54712.82029              0.41000            0.36301
# 278          0.04200    54381.55772              0.44200            0.37966
# 279          0.02600    53485.94460              0.45917            0.35991
#
# [280 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['Location', 'Year', 'Evic_rt', 'Family%', 'hpd_compl', 'nypd_compl',
#        '%White', '%Latino', '%Black', '%Asian', 'Race_%other', 'max_race',
#        'poverty_pct', 'unemployment_rt', 'median_income',
#        'limited_english_pct', 'severe_burden_pct'],
#       dtype='object')

# %% [markdown]
# ## Correlation

# %%
# important: choose variables from the corr. output

# question: is it printing the order of the variables correctly?

# %%
plt.subplots(figsize=(20,13))
sns.heatmap(df.drop(columns=['Year', 'Location']).corr(), annot=True, linewidths=.1, cmap="YlGnBu")

# %%
# same eliminating the "duplicated" part of the heatmap

mask = np.zeros_like(df.drop(columns=['Year', 'Location']).corr())
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(20, 13))
    ax = sns.heatmap(df.drop(columns=['Year', 'Location']).corr(), annot=True, linewidths=.1, cmap="YlGnBu", mask=mask, square=True)
    #ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)

# %% [markdown]
# ## Linear regression

# %%
# to do

# %%
# univariate vs multivariate analysis

# %% [markdown]
# ## Clustering

# %%
# old version. needs to be updated with whole df.

# %%
# IMPORTANT: how to decide if gm / kmeans / dbscan...

# %%
df.head()
# Out:
#    Year    Evic_rt  LocationId   %White  %Latino   %Black   %Asian   %Other  \
# 0  2013  43.711095         101  0.71920  0.06831  0.02233  0.15648  0.03368
# 1  2014  35.407584         101  0.72273  0.06887  0.02319  0.15057  0.03464
# 2  2015  28.157475         101  0.71679  0.06837  0.02263  0.15731  0.03490
# 3  2016  26.383320         101  0.71615  0.06966  0.02227  0.15905  0.03288
# 4  2017  22.314438         101  0.72039  0.06416  0.02304  0.15709  0.03532
#
#   max_race
# 0    White
# 1    White
# 2    White
# 3    White
# 4    White

# %%
df_grouped = df.groupby(by='LocationId').mean().drop(columns='Year')
df_grouped.head()
# Out:
#               Evic_rt    %White   %Latino    %Black    %Asian    %Other
# LocationId
# 101         31.194782  0.719052  0.067874  0.022692  0.156100  0.034284
# 102         28.941069  0.719052  0.067874  0.022692  0.156100  0.034284
# 103         36.841578  0.325986  0.247874  0.073258  0.321382  0.031498
# 104         36.255489  0.612156  0.148154  0.055944  0.153878  0.029870
# 105         27.107979  0.612156  0.148154  0.055944  0.153878  0.029870

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
import numpy as np

range_n_clusters = range(2,20)
for n_clusters in range_n_clusters: #try different numbers of clusters
    km = KMeans(n_clusters=n_clusters, random_state=324)
    cluster_labels = km.fit_predict(df_grouped)
    #report average Silhouette score
    silhouette_avg = silhouette_score(df_grouped, cluster_labels)
    print("For n_clusters ={},".format(n_clusters)+" the average silhouette_score is :{}".format(silhouette_avg))
# Out:
# For n_clusters =2, the average silhouette_score is :0.6631065456269508
# For n_clusters =3, the average silhouette_score is :0.6481202380459198
# For n_clusters =4, the average silhouette_score is :0.6545702952197738
# For n_clusters =5, the average silhouette_score is :0.6543559357246764
# For n_clusters =6, the average silhouette_score is :0.6576563355338935
# For n_clusters =7, the average silhouette_score is :0.6768861291230385
# For n_clusters =8, the average silhouette_score is :0.7059091303468139
# For n_clusters =9, the average silhouette_score is :0.6937186906859555
# For n_clusters =10, the average silhouette_score is :0.6622145352718898
# For n_clusters =11, the average silhouette_score is :0.6604634007051898
# For n_clusters =12, the average silhouette_score is :0.661444819071158
# For n_clusters =13, the average silhouette_score is :0.6488753193405385
# For n_clusters =14, the average silhouette_score is :0.6666864085419211
# For n_clusters =15, the average silhouette_score is :0.6758977369597875
# For n_clusters =16, the average silhouette_score is :0.6839081739057976
# For n_clusters =17, the average silhouette_score is :0.6720443285526
# For n_clusters =18, the average silhouette_score is :0.6577490717313212
# For n_clusters =19, the average silhouette_score is :0.664932724413874

# %%
# nr of clusters
k = 8

# apply clustering to city locations based on activity proportion
gm = GaussianMixture(n_components=k,random_state=324).fit(df_grouped)
gm.labels_ = gm.predict(df_grouped) # get labels

result = pd.DataFrame({'LocationId': df_grouped.index, 'label': gm.labels_}).reset_index(drop=True)
result.head()
# Out:
#    LocationId  label
# 0         101      7
# 1         102      7
# 2         103      1
# 3         104      1
# 4         105      7

# %%
cd = gpd.read_file('https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/NYC_Community_Districts/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson')

# %%
#visualize the clustering together with the categorical activity ridership of each cluster
result['label'] = result['label'].astype(str)
fig,ax = plt.subplots(nrows=1, ncols=1,figsize=(20,10))

cd.merge(result,left_on='BoroCD',right_on='LocationId',how='left').plot(column='label',cmap='tab20b', 
                                    legend=True,ax=ax)

# %%
cd = gpd.read_file('https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/NYC_Community_Districts/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson')
dfGeo = cd.merge(df,left_on='BoroCD',right_on='LocationId',how='left')
dfGeo.head()
# Out:
#    OBJECTID  BoroCD   Shape__Area  Shape__Length  \
# 0         1     101  4.268909e+07   74168.382652
# 1         1     101  4.268909e+07   74168.382652
# 2         1     101  4.268909e+07   74168.382652
# 3         1     101  4.268909e+07   74168.382652
# 4         1     101  4.268909e+07   74168.382652
#
#                                             geometry    Year    Evic_rt  \
# 0  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...  2013.0  43.711095
# 1  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...  2014.0  35.407584
# 2  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...  2015.0  28.157475
# 3  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...  2016.0  26.383320
# 4  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...  2017.0  22.314438
#
#    LocationId   %White  %Latino   %Black   %Asian   %Other max_race
# 0       101.0  0.71920  0.06831  0.02233  0.15648  0.03368    White
# 1       101.0  0.72273  0.06887  0.02319  0.15057  0.03464    White
# 2       101.0  0.71679  0.06837  0.02263  0.15731  0.03490    White
# 3       101.0  0.71615  0.06966  0.02227  0.15905  0.03288    White
# 4       101.0  0.72039  0.06416  0.02304  0.15709  0.03532    White

# %%
clusters = dfGeo.reset_index().merge(result,left_on='BoroCD',right_on='LocationId').\
                groupby(['label']).sum().reset_index(drop=True)
clusters
# Out:
#    index  OBJECTID  BoroCD   Shape__Area  Shape__Length      Year  \
# 0   5600      1245    9825  4.785041e+09   2.364819e+06   70525.0
# 1  10410      2330   18875  1.039216e+10   4.745358e+06  120900.0
# 2   3390       740    7175  2.265215e+09   2.048674e+06   60450.0
# 3  10420      2305   17980  7.299654e+09   5.059271e+06  110825.0
# 4   2250       495    4150  1.607587e+09   8.017503e+05   30225.0
# 5    755       165    2035  5.017480e+08   3.239390e+05   20150.0
# 6   4540       990    7840  3.462617e+09   1.534198e+06   60450.0
# 7   5490      1235   12295  4.608956e+09   3.333731e+06  110825.0
#
#        Evic_rt  LocationId_x    %White   %Latino    %Black    %Asian   %Other  \
# 0  4421.427991        9825.0   9.26928  11.81688   9.33404   3.64708  0.93279
# 1  2481.246606       18875.0  29.68063  10.92792   3.15869  14.81269  1.42005
# 2  6507.948932        7175.0   2.60205  18.00203   8.28237   0.68193  0.43169
# 3  4545.071512       17980.0  12.27602  18.67465  14.34172   7.44050  2.26712
# 4  2643.158797        4150.0   0.44135   5.80157   7.83812   0.61502  0.30395
# 5  2584.334365        2035.0   0.30352   6.36680   3.06040   0.12515  0.14415
# 6  4616.751474        7840.0   3.78795   6.26511  17.77107   1.27000  0.90582
# 7  1597.023210       12295.0  33.94959   9.14615   2.00903   8.43347  1.46183
#
#    LocationId_y
# 0          9825
# 1         18875
# 2          7175
# 3         17980
# 4          4150
# 5          2035
# 6          7840
# 7         12295

# %%
sel_cols = ['Evic_rt', '%White', '%Latino', '%Black', '%Asian', '%Other']
clusters = clusters[sel_cols]

# normalize values
clusters_norm = clusters.div(clusters.sum(axis=1), axis=0)
clusters_norm['label'] = range(8)
clusters_norm
# Out:
#     Evic_rt    %White   %Latino    %Black    %Asian    %Other  label
# 0  0.992146  0.002080  0.002652  0.002095  0.000818  0.000209      0
# 1  0.976390  0.011680  0.004300  0.001243  0.005829  0.000559      1
# 2  0.995411  0.000398  0.002753  0.001267  0.000104  0.000066      2
# 3  0.988044  0.002669  0.004060  0.003118  0.001617  0.000493      3
# 4  0.994357  0.000166  0.002183  0.002949  0.000231  0.000114      4
# 5  0.996145  0.000117  0.002454  0.001180  0.000048  0.000056      5
# 6  0.993544  0.000815  0.001348  0.003824  0.000273  0.000195      6
# 7  0.966707  0.020550  0.005536  0.001216  0.005105  0.000885      7

# %%
# PROBLEMITA: evict rate values are too high compared to %race

# %%
# plot bar

clusters_norm[sel_cols].plot.bar(stacked=True, cmap='tab20b')
plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.xlabel('cluster labels')
plt.ylabel('variable%')
# Out:
# Text(0, 0.5, 'variable%')
